# %%
import numpy as np
import pandas as pd

# %%
df_test_y = pd.read_csv("y_test_pred.csv")
df_test_y
# Out:
#      filename   sexe date_accident date_consolidation
# 0         770  homme    1991-04-09               n.c.
# 1         771  homme    2005-06-10         2010-01-19
# 2         772  femme    1997-09-26               n.c.
# 3         773  femme    1982-08-07         1982-11-07
# 4         774  homme    1996-11-26               n.c.
# ..        ...    ...           ...                ...
# 252      1022  femme    2007-06-16         2009-06-16
# 253      1023  femme    2000-09-12               n.c.
# 254      1024  homme    2007-10-13               n.c.
# 255      1025  homme    2007-07-19               n.c.
# 256      1026  femme    2005-05-23               n.c.
#
# [257 rows x 4 columns]

# %%
df_test_x = pd.read_csv("test_folder_predilex/test_folder/x_test_ids.csv")
df_test_x
# Out:
#        ID                filename
# 0     770        Agen_1400036.txt
# 1     771       Agen_20011399.txt
# 2     772          Agen_21013.txt
# 3     773          Agen_31076.txt
# 4     774           Agen_3436.txt
# ..    ...                     ...
# 252  1022  Versailles_1102996.txt
# 253  1023  Versailles_1404397.txt
# 254  1024  Versailles_1508232.txt
# 255  1025    Versailles_45687.txt
# 256  1026    Versailles_64952.txt
#
# [257 rows x 2 columns]

# %%
df_test = df_test_x.set_index('ID').join(df_test_y.set_index('filename'))#.reset_index().drop('ID',axis=1)
df_test
# Out:
#                     filename   sexe date_accident date_consolidation
# ID
# 770         Agen_1400036.txt  homme    1991-04-09               n.c.
# 771        Agen_20011399.txt  homme    2005-06-10         2010-01-19
# 772           Agen_21013.txt  femme    1997-09-26               n.c.
# 773           Agen_31076.txt  femme    1982-08-07         1982-11-07
# 774            Agen_3436.txt  homme    1996-11-26               n.c.
# ...                      ...    ...           ...                ...
# 1022  Versailles_1102996.txt  femme    2007-06-16         2009-06-16
# 1023  Versailles_1404397.txt  femme    2000-09-12               n.c.
# 1024  Versailles_1508232.txt  homme    2007-10-13               n.c.
# 1025    Versailles_45687.txt  homme    2007-07-19               n.c.
# 1026    Versailles_64952.txt  femme    2005-05-23               n.c.
#
# [257 rows x 4 columns]

# %%
df_test['contenu'] = df_test

# %%
for i in df_test.filename:
    print(i)
# Out:
# Agen_1400036.txt
# Agen_20011399.txt
# Agen_21013.txt
# Agen_31076.txt
# Agen_3436.txt
# Agen_400518.txt
# Agen_51586.txt
# Agen_60001230.txt
# Agen_600507.txt
# Agen_600946.txt
# Agen_601230.txt
# Aix-en-Provence_103075.txt
# Aix-en-Provence_119417.txt
# Aix-en-Provence_1518823.txt
# Aix-en-Provence_200264.txt
# Aix-en-Provence_202313.txt
# Aix-en-Provence_205257.txt
# Aix-en-Provence_205526.txt
# Aix-en-Provence_208038.txt
# Aix-en-Provence_216102.txt
# Aix-en-Provence_219595.txt
# Aix-en-Provence_302882.txt
# Aix-en-Provence_312878.txt
# Aix-en-Provence_321022.txt
# Aix-en-Provence_514513.txt
# Aix-en-Provence_520670.txt
# Aix-en-Provence_522529.txt
# Aix-en-Provence_524164.txt
# Aix-en-Provence_59661.txt
# Aix-en-Provence_6005014.txt
# Aix-en-Provence_601239.txt
# Aix-en-Provence_602536.txt
# Aix-en-Provence_609072.txt
# Aix-en-Provence_614031.txt
# Aix-en-Provence_614346.txt
# Aix-en-Provence_614635.txt
# Aix-en-Provence_615561.txt
# Aix-en-Provence_617703.txt
# ...

# %%
text_list = []

for i in df_test.filename:
    f=open("test_folder_predilex/test_folder/txt_files/"+i,"r",encoding="utf-8")
    text_list.append(f.read().replace('\xa0','').replace('\n',' '))

df_test['contenu']=text_list

# %%
text_list[0]
# Out:
# 'Le : 12/11/2019   Cour d’appel d’Agen   chambre sociale   Audience publique du 27 janvier 2015   N° de RG: 14/00036    Infirme partiellement, réforme ou modifie certaines dispositions de la décision déférée     REPUBLIQUE FRANCAISE  AU NOM DU PEUPLE FRANCAIS   ARRÊT no 45     COUR D’APPEL D’AGEN   Chambre Sociale      ARRÊT DU   27 JANVIER 2015     AC/ SB      R. G. 14/ 00036     Lucien X...    C/    Société SADEFA INDUSTRIES    Me Christophe Y... es qualité de représentant des créanciers de la Société SADEFA INDUSTRIES    CAISSE PRIMAIRE D’ASSURANCE MALADIE DE LOT ET GARONNE    FONDS D’INDEMNISATION DES VICTIMES DE L’AMIANTE      Prononcé à l’audience publique du vingt-sept janvier deux mille quinze par Aurélie PRACHE, Conseillère, faisant fonction de Présidente de Chambre, assistée de Nicole CUESTA, Greffière.     La COUR d’APPEL D’AGEN, CHAMBRE SOCIALE, dans l’affaire     ENTRE :     Lucien X...   né le 20 octobre 1937 à TOMBEBOEUF (47380)  ...   47500 CONDEZAYGUES    Représenté 
# ...

# %%
df_test
# Out:
#                     filename   sexe date_accident date_consolidation  \
# ID
# 770         Agen_1400036.txt  homme    1991-04-09               n.c.
# 771        Agen_20011399.txt  homme    2005-06-10         2010-01-19
# 772           Agen_21013.txt  femme    1997-09-26               n.c.
# 773           Agen_31076.txt  femme    1982-08-07         1982-11-07
# 774            Agen_3436.txt  homme    1996-11-26               n.c.
# ...                      ...    ...           ...                ...
# 1022  Versailles_1102996.txt  femme    2007-06-16         2009-06-16
# 1023  Versailles_1404397.txt  femme    2000-09-12               n.c.
# 1024  Versailles_1508232.txt  homme    2007-10-13               n.c.
# 1025    Versailles_45687.txt  homme    2007-07-19               n.c.
# 1026    Versailles_64952.txt  femme    2005-05-23               n.c.
#
#                                                 contenu
# ID
# 770   Le : 12/11/2019   Cour d’appel d’Agen   chambr...
# ...

# %%
words = set()
for i in df_test.contenu:
    for j in i.split():
        words.add(j)

# %%
words
# Out:
# {'garantir',
#  '(manifestation',
#  'fonctionné',
#  'édictées',
#  'pérennisation',
#  'd’AJACCIO,',
#  's’appuient',
#  'fondent,',
#  'Euromédecine-',
#  'IDEAL.',
#  '2000',
#  'FRANCE,',
#  'd’Alsace',
#  'craintes',
#  'routes,',
#  'circulation',
#  'Pyrénéens,',
#  'antérieure.',
#  '06/',
#  'provision),',
#  'sclérose',
#  'l’entrée',
#  'retiré',
#  'SOGNAC',
#  'n’ai',
#  'admis)',
#  's’entendent',
#  'retenait',
#  'laisser',
#  'l’équité,',
#  'V....',
#  'sous-acromiale',
#  'services,',
#  '511,',
#  '12mois',
#  '70/80,',
#  'Napoléon',
#  '199,28',
#  'aidés',
#  'FRICK,',
#  '214.',
#  'précédé',
#  'autrement,',
#  'sonde',
#  '75106-79060',
#  'GUEDARD,',
#  'ACCIDENT',
#  'ressentie',
#  '75060',
#  'pompiers',
#  'reprochés,',
#  'contusion,',
#  '1996',
#  '197',
#  'significatives',
#  'revendiqué,',
#  'LAPORTE',
#  '859,',
#  'Anna',
#  'l’opérateur,',
#  'ROYAN',
#  'ponction',
#  'délivrer',
#  'euros).',
#  'ROANNE',
#  'MENARD-SCELLE-MILLET,',
# ...

# %%
len(words)
# Out:
# 39279

# %%
#for i in words:
#    df_test['w_'+i] = np.zeros(len(df_test.filename))

# %%
df_test
# Out:
#                     filename   sexe date_accident date_consolidation  \
# ID
# 770         Agen_1400036.txt  homme    1991-04-09               n.c.
# 771        Agen_20011399.txt  homme    2005-06-10         2010-01-19
# 772           Agen_21013.txt  femme    1997-09-26               n.c.
# 773           Agen_31076.txt  femme    1982-08-07         1982-11-07
# 774            Agen_3436.txt  homme    1996-11-26               n.c.
# ...                      ...    ...           ...                ...
# 1022  Versailles_1102996.txt  femme    2007-06-16         2009-06-16
# 1023  Versailles_1404397.txt  femme    2000-09-12               n.c.
# 1024  Versailles_1508232.txt  homme    2007-10-13               n.c.
# 1025    Versailles_45687.txt  homme    2007-07-19               n.c.
# 1026    Versailles_64952.txt  femme    2005-05-23               n.c.
#
#                                                 contenu  w_garantir  \
# ID
# ...
